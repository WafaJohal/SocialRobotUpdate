# %%
import pandas as pd
from pyzotero import zotero
from habanero import Crossref
import habanero as hb
import matplotlib.pyplot as plt
import seaborn as sns
from scholar import scholar

# %%
zot = zotero.Zotero(2419050, 'group', 'g0wIgs8ovYoLF0oLtFXvqT9a')
cr = Crossref()
our_coll = 'SocialRobotEdu'
our_coll_key = 'X6PKYLT6'

# %%
# fetch the zotero collection
subColl = zot.collections_sub(our_coll_key)

# %%
# parse all the items of the collection into a dataframe
df = pd.DataFrame()
for sc in subColl:
    items = zot.collection_items(sc['key'])
    for i in range(len(items)):
        data = items[i]['data']
        data.update({'wtype':sc['data']['name']})
        df = df.append(data, ignore_index=True)    
df.head()
# Out:
#                         DOI       ISSN  \
# 0                            2340-1079
# 1                            2340-1079
# 2  10.21125/inted.2020.1926  2340-1079
# 3  10.3389/frobt.2020.00015  2296-9144
# 4  10.3389/frobt.2019.00148  2296-9144
#
#                                         abstractNote            accessDate  \
# 0  For a long time now, people have dreamed of cr...  2020-03-31T02:05:50Z
# 1  Robots are currently entering the classrooms i...  2020-03-31T02:05:08Z
# 2  We report on a follow-up study of the Co-Write...  2020-03-30T00:08:16Z
# 3  The emergence and development of cognitive str...  2020-03-26T02:35:50Z
# 4  Acknowledging the benefits of active learning ...  2020-03-26T02:34:47Z
#
#   archive archiveLocation callNumber collections  \
# 0                                     [E9ILFJBI]
# 1                                     [E9ILFJBI]
# 2                                     [E9ILFJBI]
# 3                                     [E9ILFJBI]
# 4                                     [E9ILFJBI]
#
#                                             creators  date  ... numPages note  \
# 0  [{'creatorType': 'author', 'firstName': 'P.', ...  2020  ...      NaN  NaN
# 1  [{'creatorType': 'author', 'firstName': 'S.', ...  2020  ...      NaN  NaN
# 2  [{'creatorType': 'author', 'firstName': 'C.', ...  2020  ...      NaN  NaN
# 3  [{'creatorType': 'author', 'firstName': 'Vicky...  2020  ...      NaN  NaN
# 4  [{'creatorType': 'author', 'firstName': 'Rinat...  2020  ...      NaN  NaN
#
#   parentItem websiteTitle websiteType meetingName presentationType charset  \
# 0        NaN          NaN         NaN         NaN              NaN     NaN
# 1        NaN          NaN         NaN         NaN              NaN     NaN
# 2        NaN          NaN         NaN         NaN              NaN     NaN
# 3        NaN          NaN         NaN         NaN              NaN     NaN
# 4        NaN          NaN         NaN         NaN              NaN     NaN
#
#   contentType linkMode
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN
#
# [5 rows x 52 columns]

# %%
# Remove subfolder containing other review papers
df = df[df.wtype != 'Other_Related_Reviews']
df.head()
# Out:
#                         DOI       ISSN  \
# 0                            2340-1079
# 1                            2340-1079
# 2  10.21125/inted.2020.1926  2340-1079
# 3  10.3389/frobt.2020.00015  2296-9144
# 4  10.3389/frobt.2019.00148  2296-9144
#
#                                         abstractNote            accessDate  \
# 0  For a long time now, people have dreamed of cr...  2020-03-31T02:05:50Z
# 1  Robots are currently entering the classrooms i...  2020-03-31T02:05:08Z
# 2  We report on a follow-up study of the Co-Write...  2020-03-30T00:08:16Z
# 3  The emergence and development of cognitive str...  2020-03-26T02:35:50Z
# 4  Acknowledging the benefits of active learning ...  2020-03-26T02:34:47Z
#
#   archive archiveLocation callNumber collections  \
# 0                                     [E9ILFJBI]
# 1                                     [E9ILFJBI]
# 2                                     [E9ILFJBI]
# 3                                     [E9ILFJBI]
# 4                                     [E9ILFJBI]
#
#                                             creators  date  ... numPages note  \
# 0  [{'creatorType': 'author', 'firstName': 'P.', ...  2020  ...      NaN  NaN
# 1  [{'creatorType': 'author', 'firstName': 'S.', ...  2020  ...      NaN  NaN
# 2  [{'creatorType': 'author', 'firstName': 'C.', ...  2020  ...      NaN  NaN
# 3  [{'creatorType': 'author', 'firstName': 'Vicky...  2020  ...      NaN  NaN
# 4  [{'creatorType': 'author', 'firstName': 'Rinat...  2020  ...      NaN  NaN
#
#   parentItem websiteTitle websiteType meetingName presentationType charset  \
# 0        NaN          NaN         NaN         NaN              NaN     NaN
# 1        NaN          NaN         NaN         NaN              NaN     NaN
# 2        NaN          NaN         NaN         NaN              NaN     NaN
# 3        NaN          NaN         NaN         NaN              NaN     NaN
# 4        NaN          NaN         NaN         NaN              NaN     NaN
#
#   contentType linkMode
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN
#
# [5 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['DOI', 'ISSN', 'abstractNote', 'accessDate', 'archive',
#        'archiveLocation', 'callNumber', 'collections', 'creators', 'date',
#        'dateAdded', 'dateModified', 'extra', 'issue', 'itemType',
#        'journalAbbreviation', 'key', 'language', 'libraryCatalog', 'pages',
#        'publicationTitle', 'relations', 'rights', 'series', 'seriesText',
#        'seriesTitle', 'shortTitle', 'tags', 'title', 'url', 'version',
#        'volume', 'wtype', 'ISBN', 'conferenceName', 'place',
#        'proceedingsTitle', 'publisher', 'bookTitle', 'edition',
#        'numberOfVolumes', 'seriesNumber', 'numPages', 'note', 'parentItem',
#        'websiteTitle', 'websiteType', 'meetingName', 'presentationType',
#        'charset', 'contentType', 'linkMode'],
#       dtype='object')

# %%
list(range(2009,2020, 1))
# Out:
# [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %% [markdown]
# # Number of papers per year

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="wtype", data=df, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
                                              '2015', '2016', '2017', '2018', '2019', '2020'], palette='Blues')

# %% [markdown]
# # Parse data from crossref using DOI

# %%
cr_df = pd.DataFrame()
for p in range(len(df)): 
    

    if(df.at[p,'DOI'] !='' and df.at[p,'DOI'] !='nan'):
        try:
            jsdata = cr.works(ids=[df.at[p,'DOI']])
        except:
            print(df.at[p,'title'], df.at[p,'DOI'])
            print("Query failed")
            r = dict(df.loc[p])
            cr_df = cr_df.append(r, ignore_index = True)
            continue
        
        if (jsdata['status'] == 'ok'):
            r = dict(df.loc[p])
            r.update(jsdata['message'])
            r['citation_count'] =  hb.counts.citation_count(doi =df.at[p,'DOI'])
            cr_df = cr_df.append(r, ignore_index = True)

        
        
    else:
        print(df.loc[p])
# Out:
# DOI
# ISSN                                                           2340-1079
# abstractNote           For a long time now, people have dreamed of cr...
# accessDate                                          2020-03-31T02:05:50Z
# archive
# archiveLocation
# callNumber
# collections                                                   [E9ILFJBI]
# creators               [{'creatorType': 'author', 'firstName': 'P.', ...
# date                                                                2020
# dateAdded                                           2020-03-31T02:05:50Z
# dateModified                                        2020-03-31T02:05:50Z
# extra
# issue
# itemType                                                  journalArticle
# journalAbbreviation
# key                                                             2Q7M3VS3
# language                                                              en
# libraryCatalog                                         library.iated.org
# pages                                                          3275-3281
# publicationTitle                                   INTED2020 Proceedings
# relations                                                             {}
# rights
# series
# seriesText
# seriesTitle
# shortTitle
# tags                                                                  []
# title                  H.E.A.R.T. (HUMANOID EMOTIONAL ASSISTANT ROBOT...
# url                        https://library.iated.org/view/HEINSCH2020HEA
# version                                                              396
# volume
# wtype                                                               2020
# ISBN                                                                 NaN
# conferenceName                                                       NaN
# place                                                                NaN
# proceedingsTitle                                                     NaN
# publisher                                                            NaN
# bookTitle                                                            NaN
# edition                                                              NaN
# numberOfVolumes                                                      NaN
# seriesNumber                                                         NaN
# numPages                                                             NaN
# note                                                                 NaN
# parentItem                                                           NaN
# websiteTitle                                                         NaN
# websiteType                                                          NaN
# meetingName                                                          NaN
# presentationType                                                     NaN
# charset                                                              NaN
# contentType                                                          NaN
# linkMode                                                             NaN
# Name: 0, dtype: object
# DOI
# ISSN                                                           2340-1079
# abstractNote           Robots are currently entering the classrooms i...
# accessDate                                          2020-03-31T02:05:08Z
# archive
# archiveLocation
# callNumber
# collections                                                   [E9ILFJBI]
# creators               [{'creatorType': 'author', 'firstName': 'S.', ...
# date                                                                2020
# dateAdded                                           2020-03-31T02:05:08Z
# dateModified                                        2020-03-31T02:05:08Z
# extra
# issue
# itemType                                                  journalArticle
# journalAbbreviation
# key                                                             YKDGEYT3
# language                                                              en
# libraryCatalog                                         library.iated.org
# pages                                                          6636-6644
# publicationTitle                                   INTED2020 Proceedings
# relations                                                             {}
# rights
# series
# seriesText
# seriesTitle
# shortTitle
# tags                                                                  []
# title                  NEW TEACHER ROLES WITH SOCIAL ROBOTS AS ACTORS...
# url                       https://library.iated.org/view/EKSTROM2020NEW2
# version                                                              395
# volume
# wtype                                                               2020
# ISBN                                                                 NaN
# conferenceName                                                       NaN
# place                                                                NaN
# proceedingsTitle                                                     NaN
# publisher                                                            NaN
# bookTitle                                                            NaN
# edition                                                              NaN
# numberOfVolumes                                                      NaN
# seriesNumber                                                         NaN
# numPages                                                             NaN
# note                                                                 NaN
# parentItem                                                           NaN
# websiteTitle                                                         NaN
# websiteType                                                          NaN
# meetingName                                                          NaN
# presentationType                                                     NaN
# charset                                                              NaN
# contentType                                                          NaN
# linkMode                                                             NaN
# Name: 1, dtype: object

# %%
cr_df
# Out:
#                                DOI                            ISBN  \
# 0         10.21125/inted.2020.1926                 [9788409179398]
# 1         10.3389/frobt.2020.00015                             NaN
# 2         10.3389/frobt.2019.00148                             NaN
# 3          10.1145/3319502.3374822                 [9781450367462]
# 4          10.1145/3319502.3374803                 [9781450367462]
# ..                             ...                             ...
# 211     10.1109/icalt.2006.1652373                    [0769526322]
# 212     10.1109/roman.2008.4600664                 [9781424422128]
# 213   10.1007/978-3-642-03986-7_24  [9783642039850, 9783642039867]
# 214      10.3745/jips.2008.4.4.159                             NaN
# 215  10.1080/07370024.2004.9667340                             NaN
#
#                        ISSN                                             URL  \
# 0                 2340-1079      http://dx.doi.org/10.21125/inted.2020.1926
# 1               [2296-9144]      http://dx.doi.org/10.3389/frobt.2020.00015
# 2               [2296-9144]      http://dx.doi.org/10.3389/frobt.2019.00148
# 3                       NaN       http://dx.doi.org/10.1145/3319502.3374822
# 4                       NaN       http://dx.doi.org/10.1145/3319502.3374803
# ..                      ...                                             ...
# 211                     NaN    http://dx.doi.org/10.1109/icalt.2006.1652373
# 212                     NaN    http://dx.doi.org/10.1109/roman.2008.4600664
# 213  [1865-0929, 1865-0937]  http://dx.doi.org/10.1007/978-3-642-03986-7_24
# 214             [1976-913X]     http://dx.doi.org/10.3745/jips.2008.4.4.159
# 215               0737-0024                                             NaN
#
#                                           abstractNote            accessDate  \
# 0    We report on a follow-up study of the Co-Write...  2020-03-30T00:08:16Z
# 1    The emergence and development of cognitive str...  2020-03-26T02:35:50Z
# 2    Acknowledging the benefits of active learning ...  2020-03-26T02:34:47Z
# 3    Prior work in affect-aware educational robots ...            2020-03-16
# 4    Interactive learning technologies, such as rob...            2020-03-16
# ..                                                 ...                   ...
# 211  Advancement in robotic research enables robot ...
# 212  This research explores feasibility of using in...
# 213  This paper discusses the role of robots in rem...
# 214  Comparative Study on the Educational Use of Ho...  2020-02-27T01:46:55Z
# 215  Robots increasingly have the potential to inte...  2020-02-27T01:45:09Z
#
#     archive archiveLocation  \
# 0
# 1
# 2
# 3
# 4
# ..      ...             ...
# 211
# 212
# 213
# 214
# 215
#
#                                                 author bookTitle  ...  \
# 0    [{'given': 'Christia', 'family': 'Ioannou', 's...       NaN  ...
# 1    [{'given': 'Vicky', 'family': 'Charisi', 'sequ...       NaN  ...
# 2    [{'given': 'Rinat B.', 'family': 'Rosenberg-Ki...       NaN  ...
# 3    [{'given': 'Huili', 'family': 'Chen', 'sequenc...       NaN  ...
# 4    [{'given': 'Daniel P.', 'family': 'Davison', '...       NaN  ...
# ..                                                 ...       ...  ...
# 211  [{'family': 'Zhen-Jia You', 'sequence': 'first...       NaN  ...
# 212  [{'family': 'Eun-ja Hyun', 'sequence': 'first'...       NaN  ...
# 213  [{'given': 'Akihiro', 'family': 'Yorita', 'seq...       NaN  ...
# 214  [{'given': 'Jeong-Hye', 'family': 'Han', 'sequ...       NaN  ...
# 215                                                NaN       NaN  ...
#
#                     published-online  \
# 0                                NaN
# 1    {'date-parts': [[2020, 2, 18]]}
# 2    {'date-parts': [[2020, 1, 10]]}
# 3     {'date-parts': [[2020, 3, 9]]}
# 4     {'date-parts': [[2020, 3, 9]]}
# ..                               ...
# 211                              NaN
# 212                              NaN
# 213                              NaN
# 214                              NaN
# 215                              NaN
#
#                                              reference  \
# 0                                                  NaN
# 1    [{'key': 'B1', 'author': 'Alves-Oliveira', 'fi...
# 2    [{'key': 'B1', 'doi-asserted-by': 'publisher',...
# 3    [{'key': 'e_1_3_2_1_1_1', 'unstructured': 'Ton...
# 4    [{'key': 'e_1_3_2_1_1_1', 'author': 'Baxter P....
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213  [{'key': '24_CR1', 'unstructured': 'Unesco, Op...
# 214                                                NaN
# 215                                                NaN
#
#                                   update-policy  publisher-location abstract  \
# 0                                           NaN                 NaN      NaN
# 1    http://dx.doi.org/10.3389/crossmark-policy                 NaN      NaN
# 2    http://dx.doi.org/10.3389/crossmark-policy                 NaN      NaN
# 3                                           NaN   New York, NY, USA      NaN
# 4                                           NaN   New York, NY, USA      NaN
# ..                                          ...                 ...      ...
# 211                                         NaN                 NaN      NaN
# 212                                         NaN                 NaN      NaN
# 213                                         NaN  Berlin, Heidelberg      NaN
# 214                                         NaN                 NaN      NaN
# 215                                         NaN                 NaN      NaN
#
#                                          journal-issue     page subject  \
# 0                                                  NaN      NaN     NaN
# 1                                                  NaN      NaN     NaN
# 2                                                  NaN      NaN     NaN
# 3                                                  NaN      NaN     NaN
# 4                                                  NaN      NaN     NaN
# ..                                                 ...      ...     ...
# 211                                                NaN      NaN     NaN
# 212                                                NaN      NaN     NaN
# 213                                                NaN  204-213     NaN
# 214  {'published-print': {'date-parts': [[2008, 12,...  159-168     NaN
# 215                                                NaN      NaN     NaN
#
#     assertion article-number
# 0         NaN            NaN
# 1         NaN            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# ..        ...            ...
# 211       NaN            NaN
# 212       NaN            NaN
# 213       NaN            NaN
# 214       NaN            NaN
# 215       NaN            NaN
#
# [216 rows x 92 columns]

# %%
cr_df.drop(['rights','accessDate','archive','archiveLocation','callNumber','charset','content-domain'
            ,'contentType', 'dateAdded','dateModified','edition','funder','language','linkMode',
           'meetingName','note','numberOfVolumes','original-title','presentationType',
           'score','seriesNumber','seriesText','seriesTitle','short-title'], axis=1, inplace =True)

# %%
cr_df.to_csv('CrossRef_DataFrame.csv', index=False)

# %% [markdown]
# # Merge CrossRef with Belpaeme et al

# %%
belpaeme2018 = pd.read_excel('Update Meta analysis of robots for learning literature (Science Robotics).xlsx', index = False)
belpaeme2018
# Out:
#         ID                           DOI  \
# 0      NaN                           NaN
# 1      1.0  10.1007/978-3-642-34103-8_41
# 2      2.0     10.1142/S0219843614500224
# 3      3.0    10.1109/ICRoM.2014.6990994
# 4      4.0     10.1007/s12369-015-0286-y
# ..     ...                           ...
# 306  110.0  10.1007/978-3-319-42975-5_23
# 307    NaN                           NaN
# 308  111.0      10.1109/MRA.2016.2546700
# 309  112.0      10.1109/CEC.2016.7743956
# 310    NaN                           NaN
#
#                                                  Paper      Country  \
# 0                                                  NaN          NaN
# 1                      Abildgaard JR, Scharfe H (2012)      Denmark
# 2             Alemi M, Meghdari A, Ghazisaedy M (2014)         Iran
# 3      Alemi M, Meghdari A, Basiri NM, Taheri A (2015)         Iran
# 4             Alemi M, Meghdari A, Ghazisaedy M (2015)         Iran
# ..                                                 ...          ...
# 306  de Haas, Smeekens, Njeri, Haselager, et al (2016)  Netherlands
# 307                                                NaN          NaN
# 308  Lemaignan, Jacq, Hood, Garcia, Paiva, Dillenbo...  Switzerland
# 309                       Suzuki, Yamada, Kanoh (2016)        Japan
# 310                                                NaN          NaN
#
#                                             Comparison  \
# 0                                                  NaN
# 1                            male vs female perception
# 2                          robot + human vs just human
# 3    pre vs mid vs post vs delayed post test of lea...
# 4                          robot + human vs just human
# ..                                                 ...
# 306  levels of socially complex robot interactions ...
# 307  levels of socially complex robot interactions ...
# 308                              no robot manipulation
# 309  nodding+hinting robot vs hinting only robot vs...
# 310                                                NaN
#
#     Robot vs human/screen/alternative Robot/s used (?)  \
# 0                                 NaN              NaN
# 1                                 NaN      Geminoid-DK
# 2                      robot vs human              Nao
# 3                                 NaN              Nao
# 4                      robot vs human              Nao
# ..                                ...              ...
# 306                               NaN              Nao
# 307                               NaN              Nao
# 308                               NaN              Nao
# 309                               NaN            ifbot
# 310                               NaN            ifbot
#
#                                                 Design  \
# 0                                                  NaN
# 1              1 condition, 2 groups, between subjects
# 2                                     between subjects
# 3                              no condition comparison
# 4                       2 conditions, between subjects
# ..                                                 ...
# 306                     4 conditions, between subjects
# 307                     4 conditions, between subjects
# 308                            no condition comparison
# 309  2 conditions (but includes previous study data...
# 310                                                NaN
#
#               Cognitive/Affective Reported effect size  ... Coded by  \
# 0                             NaN                  NaN  ...      NaN
# 1    affective (robot perception)         not reported  ...       JK
# 2            cognitive (learning)    0.3 (eta squared)  ...       JK
# 3            cognitive (learning)         not reported  ...       JK
# 4             affective (anxiety)         not reported  ...       JK
# ..                            ...                  ...  ...      ...
# 306           affective (emotion)                  NaN  ...       EA
# 307           affective (arousal)                  NaN  ...       EA
# 308                           NaN                  NaN  ...       EA
# 309   cognitive (task completion)                  NaN  ...       EA
# 310                           NaN                  NaN  ...       EA
#
#     Curriculum    Location             Context\n nb students per robot  \
# 0          NaN         NaN                   NaN                   NaN
# 1          HCI  university  University classroom                 150.0
# 2           L2      school           junior High                  15.0
# 3           L2      school           junior High                  15.0
# 4           L2      school           junior High                  15.0
# ..         ...         ...                   ...                   ...
# 306        NaN         NaN                   NaN                   NaN
# 307        NaN         NaN                   NaN                   NaN
# 308        NaN         NaN                   NaN                   NaN
# 309        NaN         NaN                   NaN                   NaN
# 310        NaN         NaN                   NaN                   NaN
#
#     Communicative gestures vs functional actions  \
# 0                                            NaN
# 1                                             CO
# 2                                             CO
# 3                                             CO
# 4                                             CO
# ..                                           ...
# 306                                          NaN
# 307                                          NaN
# 308                                          NaN
# 309                                          NaN
# 310                                          NaN
#
#                                               Autonomy  \
# 0    (M) Manual (T) Teleoperation (AssT)Assisted Te...
# 1                                                    T
# 2                                             Scripted
# 3                                             Scripted
# 4                                             Scripted
# ..                                                 ...
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
#     Contain Retain component?  Material Updated by
# 0                         NaN       NaN        NaN
# 1                         NaN    Laptop         WJ
# 2                         NaN         -         WJ
# 3                         NaN         -         WJ
# 4                         NaN         -         WJ
# ..                        ...       ...        ...
# 306                       NaN       NaN        NaN
# 307                       NaN       NaN        NaN
# 308                       NaN       NaN        NaN
# 309                       NaN       NaN        NaN
# 310                       NaN       NaN        NaN
#
# [311 rows x 52 columns]

# %%
belpaeme2018.dropna(subset=['DOI'], inplace=True) # remove papers without DOI
belpaeme2018.reset_index(inplace=True)

# %%
cr_anno = pd.merge(cr_df, belpaeme2018, on=['DOI'], how='left')

# %%
cr_anno.to_excel('CrossRef_DataFrame_wAnno.xlsx', index=False)

# %% [markdown]
# # Number of citation per publication year

# %%
plt.figure(figsize=(20,10))
ax = sns.barplot(x="wtype",y='citation_count', data=cr_anno, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
                                              '2015', '2016', '2017', '2018', '2019', '2020'], palette='Blues')

# %%
cr_anno['is-referenced-by-count'].fillna(0, inplace=True)
cr_anno.sort_values(by='is-referenced-by-count', inplace = True)

primar = cr_anno.tail(10)[['DOI','URL',
       'proceedingsTitle', 'publicationTitle', 'published-online',
       'published-print', 'publisher', 'publisher-location', 'reference','author', 'bookTitle', 'citation_count', 'collections',
       'conferenceName']]

# %%
primar.to_csv('primar.csv')

# %%
for p in primar.index

# %%
# Publcation venue

# %%
cr_df.columns
# Out:
# Index(['DOI', 'ISBN', 'ISSN', 'URL', 'abstractNote', 'accessDate',
#        'alternative-id', 'archive', 'archiveLocation', 'author', 'bookTitle',
#        'callNumber', 'charset', 'citation_count', 'collections',
#        'conferenceName', 'container-title', 'content-domain', 'contentType',
#        'created', 'creators', 'date', 'dateAdded', 'dateModified', 'deposited',
#        'edition', 'event', 'extra', 'funder', 'indexed',
#        'is-referenced-by-count', 'isbn-type', 'issue', 'issued', 'itemType',
#        'journalAbbreviation', 'key', 'language', 'libraryCatalog', 'linkMode',
#        'meetingName', 'member', 'note', 'numberOfVolumes', 'original-title',
#        'pages', 'parentItem', 'place', 'prefix', 'presentationType',
#        'proceedingsTitle', 'publicationTitle', 'published-online',
#        'published-print', 'publisher', 'publisher-location', 'reference',
#        'reference-count', 'references-count', 'relation', 'relations',
#        'rights', 'score', 'series', 'seriesNumber', 'seriesText',
#        'seriesTitle', 'short-container-title', 'short-title', 'shortTitle',
#        'source', 'subtitle', 'tags', 'title', 'type', 'url', 'version',
#        'volume', 'websiteTitle', 'websiteType', 'wtype', 'abstract',
#        'issn-type', 'journal-issue', 'link', 'page', 'subject', 'assertion',
#        'update-policy', 'license', 'article-number'],
#       dtype='object')

# %%
cr_df['parentItem'].unique()
# Out:
# array([nan, '3V65JG78', '9HCNUD9A'], dtype=object)

# %%
plt.figure(figsize=(20,10))
ax = sns.barplot(x="wtype",y='citation_count', data=cr_df, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
                                              '2015', '2016', '2017', '2018', '2019', '2020'], palette='Blues')

# %%
# Out:
#         ID                           DOI  \
# 0      NaN                           NaN
# 1      1.0  10.1007/978-3-642-34103-8_41
# 2      2.0     10.1142/S0219843614500224
# 3      3.0    10.1109/ICRoM.2014.6990994
# 4      4.0     10.1007/s12369-015-0286-y
# ..     ...                           ...
# 306  110.0  10.1007/978-3-319-42975-5_23
# 307    NaN                           NaN
# 308  111.0      10.1109/MRA.2016.2546700
# 309  112.0      10.1109/CEC.2016.7743956
# 310    NaN                           NaN
#
#                                                  Paper      Country  \
# 0                                                  NaN          NaN
# 1                      Abildgaard JR, Scharfe H (2012)      Denmark
# 2             Alemi M, Meghdari A, Ghazisaedy M (2014)         Iran
# 3      Alemi M, Meghdari A, Basiri NM, Taheri A (2015)         Iran
# 4             Alemi M, Meghdari A, Ghazisaedy M (2015)         Iran
# ..                                                 ...          ...
# 306  de Haas, Smeekens, Njeri, Haselager, et al (2016)  Netherlands
# 307                                                NaN          NaN
# 308  Lemaignan, Jacq, Hood, Garcia, Paiva, Dillenbo...  Switzerland
# 309                       Suzuki, Yamada, Kanoh (2016)        Japan
# 310                                                NaN          NaN
#
#                                             Comparison  \
# 0                                                  NaN
# 1                            male vs female perception
# 2                          robot + human vs just human
# 3    pre vs mid vs post vs delayed post test of lea...
# 4                          robot + human vs just human
# ..                                                 ...
# 306  levels of socially complex robot interactions ...
# 307  levels of socially complex robot interactions ...
# 308                              no robot manipulation
# 309  nodding+hinting robot vs hinting only robot vs...
# 310                                                NaN
#
#     Robot vs human/screen/alternative Robot/s used (?)  \
# 0                                 NaN              NaN
# 1                                 NaN      Geminoid-DK
# 2                      robot vs human              Nao
# 3                                 NaN              Nao
# 4                      robot vs human              Nao
# ..                                ...              ...
# 306                               NaN              Nao
# 307                               NaN              Nao
# 308                               NaN              Nao
# 309                               NaN            ifbot
# 310                               NaN            ifbot
#
#                                                 Design  \
# 0                                                  NaN
# 1              1 condition, 2 groups, between subjects
# 2                                     between subjects
# 3                              no condition comparison
# 4                       2 conditions, between subjects
# ..                                                 ...
# 306                     4 conditions, between subjects
# 307                     4 conditions, between subjects
# 308                            no condition comparison
# 309  2 conditions (but includes previous study data...
# 310                                                NaN
#
#               Cognitive/Affective Reported effect size  ... Coded by  \
# 0                             NaN                  NaN  ...      NaN
# 1    affective (robot perception)         not reported  ...       JK
# 2            cognitive (learning)    0.3 (eta squared)  ...       JK
# 3            cognitive (learning)         not reported  ...       JK
# 4             affective (anxiety)         not reported  ...       JK
# ..                            ...                  ...  ...      ...
# 306           affective (emotion)                  NaN  ...       EA
# 307           affective (arousal)                  NaN  ...       EA
# 308                           NaN                  NaN  ...       EA
# 309   cognitive (task completion)                  NaN  ...       EA
# 310                           NaN                  NaN  ...       EA
#
#     Curriculum    Location             Context\n nb students per robot  \
# 0          NaN         NaN                   NaN                   NaN
# 1          HCI  university  University classroom                 150.0
# 2           L2      school           junior High                  15.0
# 3           L2      school           junior High                  15.0
# 4           L2      school           junior High                  15.0
# ..         ...         ...                   ...                   ...
# 306        NaN         NaN                   NaN                   NaN
# 307        NaN         NaN                   NaN                   NaN
# 308        NaN         NaN                   NaN                   NaN
# 309        NaN         NaN                   NaN                   NaN
# 310        NaN         NaN                   NaN                   NaN
#
#     Communicative gestures vs functional actions  \
# 0                                            NaN
# 1                                             CO
# 2                                             CO
# 3                                             CO
# 4                                             CO
# ..                                           ...
# 306                                          NaN
# 307                                          NaN
# 308                                          NaN
# 309                                          NaN
# 310                                          NaN
#
#                                               Autonomy  \
# 0    (M) Manual (T) Teleoperation (AssT)Assisted Te...
# 1                                                    T
# 2                                             Scripted
# 3                                             Scripted
# 4                                             Scripted
# ..                                                 ...
# 306                                                NaN
# 307                                                NaN
# 308                                                NaN
# 309                                                NaN
# 310                                                NaN
#
#     Contain Retain component?  Material Updated by
# 0                         NaN       NaN        NaN
# 1                         NaN    Laptop         WJ
# 2                         NaN         -         WJ
# 3                         NaN         -         WJ
# 4                         NaN         -         WJ
# ..                        ...       ...        ...
# 306                       NaN       NaN        NaN
# 307                       NaN       NaN        NaN
# 308                       NaN       NaN        NaN
# 309                       NaN       NaN        NaN
# 310                       NaN       NaN        NaN
#
# [311 rows x 52 columns]

# %%
anno.dropna(subset=['DOI'], inplace=True)
anno.reset_index(inplace=True)

# %%
anno
# Out:
#     index     ID                             DOI  \
# 0       1    1.0    10.1007/978-3-642-34103-8_41
# 1       2    2.0       10.1142/S0219843614500224
# 2       3    3.0      10.1109/ICRoM.2014.6990994
# 3       4    4.0       10.1007/s12369-015-0286-y
# 4       5    5.0     10.1007/978-3-319-25554-5_3
# ..    ...    ...                             ...
# 91    299  107.0  10.2307/jeductechsoci.19.1.337
# 92    303  108.0       10.1016/j.chb.2016.06.005
# 93    306  110.0    10.1007/978-3-319-42975-5_23
# 94    308  111.0        10.1109/MRA.2016.2546700
# 95    309  112.0        10.1109/CEC.2016.7743956
#
#                                                 Paper      Country  \
# 0                     Abildgaard JR, Scharfe H (2012)      Denmark
# 1            Alemi M, Meghdari A, Ghazisaedy M (2014)         Iran
# 2     Alemi M, Meghdari A, Basiri NM, Taheri A (2015)         Iran
# 3            Alemi M, Meghdari A, Ghazisaedy M (2015)         Iran
# 4   Alves-Oliveira P, Ribeiro T, Petisca S, di Tul...     Portugal
# ..                                                ...          ...
# 91                      Hong, Huang, Hsu, Shen (2016)       Taiwan
# 92   Edwards, Edwards, Spence, Harris, Gambino (2016)          USA
# 93  de Haas, Smeekens, Njeri, Haselager, et al (2016)  Netherlands
# 94  Lemaignan, Jacq, Hood, Garcia, Paiva, Dillenbo...  Switzerland
# 95                       Suzuki, Yamada, Kanoh (2016)        Japan
#
#                                            Comparison  \
# 0                           male vs female perception
# 1                         robot + human vs just human
# 2   pre vs mid vs post vs delayed post test of lea...
# 3                         robot + human vs just human
# 4    expectation vs satisfaction of robot interaction
# ..                                                ...
# 91                                  robot vs no robot
# 92               robot-as-teacher vs teacher-as-robot
# 93  levels of socially complex robot interactions ...
# 94                              no robot manipulation
# 95  nodding+hinting robot vs hinting only robot vs...
#
#    Robot vs human/screen/alternative    Robot/s used (?)  \
# 0                                NaN         Geminoid-DK
# 1                     robot vs human                 Nao
# 2                                NaN                 Nao
# 3                     robot vs human                 Nao
# 4                                NaN                 Nao
# ..                               ...                 ...
# 91              robot vs alternative             Bioloid
# 92                               NaN  MantaroBot Classic
# 93                               NaN                 Nao
# 94                               NaN                 Nao
# 95                               NaN               ifbot
#
#                                                Design  \
# 0             1 condition, 2 groups, between subjects
# 1                                    between subjects
# 2                             no condition comparison
# 3                      2 conditions, between subjects
# 4                                                 NaN
# ..                                                ...
# 91                     2 conditions, between subjects
# 92                     2 conditions, between subjects
# 93                     4 conditions, between subjects
# 94                            no condition comparison
# 95  2 conditions (but includes previous study data...
#
#                          Cognitive/Affective  ... Coded by      Curriculum  \
# 0               affective (robot perception)  ...       JK             HCI
# 1                       cognitive (learning)  ...       JK              L2
# 2                       cognitive (learning)  ...       JK              L2
# 3                        affective (anxiety)  ...       JK              L2
# 4                   affective (satisfaction)  ...       JK  sustainability
# ..                                       ...  ...      ...             ...
# 91  cognitive (overall learning achievement)  ...       EA             NaN
# 92            affective (source credibility)  ...       EA             NaN
# 93                       affective (emotion)  ...       EA             NaN
# 94                                       NaN  ...       EA             NaN
# 95               cognitive (task completion)  ...       EA             NaN
#
#       Location             Context\n nb students per robot  \
# 0   university  University classroom                 150.0
# 1       school           junior High                  15.0
# 2       school           junior High                  15.0
# 3       school           junior High                  15.0
# 4       school           high school                   2.0
# ..         ...                   ...                   ...
# 91         NaN                   NaN                   NaN
# 92         NaN                   NaN                   NaN
# 93         NaN                   NaN                   NaN
# 94         NaN                   NaN                   NaN
# 95         NaN                   NaN                   NaN
#
#    Communicative gestures vs functional actions  Autonomy  \
# 0                                            CO         T
# 1                                            CO  Scripted
# 2                                            CO  Scripted
# 3                                            CO  Scripted
# 4                                     CO+Dietic       WOZ
# ..                                          ...       ...
# 91                                          NaN       NaN
# 92                                          NaN       NaN
# 93                                          NaN       NaN
# 94                                          NaN       NaN
# 95                                          NaN       NaN
#
#    Contain Retain component?                 Material  Updated by
# 0                        NaN                   Laptop          WJ
# 1                        NaN                        -          WJ
# 2                        NaN                        -          WJ
# 3                        NaN                        -          WJ
# 4                        NaN  interactive touch table          WJ
# ..                       ...                      ...         ...
# 91                       NaN                      NaN         NaN
# 92                       NaN                      NaN         NaN
# 93                       NaN                      NaN         NaN
# 94                       NaN                      NaN         NaN
# 95                       NaN                      NaN         NaN
#
# [96 rows x 53 columns]

# %%
cr_anno = pd.merge(cr_df, anno, on=['DOI'], how='left')

# %%
cr_anno.to_excel('CrossRef_DataFrame_wAnno.xlsx', index=False)

# %%
cr_anno.sort_values(by='citation_count').head(10)
# Out:
#                                 DOI                            ISBN  \
# 0          10.21125/inted.2020.1926                 [9788409179398]
# 119    10.1007/978-3-030-06134-0_42  [9783030061333, 9783030061340]
# 118     10.1109/devlrn.2018.8761028                 [9781538661109]
# 117         10.1145/3284432.3284433                 [9781450359535]
# 115  10.1109/colcomcon.2019.8809113                 [9781728135038]
# 111    10.1007/978-3-030-35888-4_56  [9783030358877, 9783030358884]
# 110      10.1007/s12369-019-00609-9                             NaN
# 108    10.1007/978-3-319-78452-6_11  [9783319784519, 9783319784526]
# 106                 10.1145/3366422                             NaN
# 103       10.1007/s11370-018-0266-9                             NaN
#
#                        ISSN                                               URL  \
# 0                 2340-1079        http://dx.doi.org/10.21125/inted.2020.1926
# 119  [1867-8211, 1867-822X]    http://dx.doi.org/10.1007/978-3-030-06134-0_42
# 118                     NaN     http://dx.doi.org/10.1109/devlrn.2018.8761028
# 117                     NaN         http://dx.doi.org/10.1145/3284432.3284433
# 115                     NaN  http://dx.doi.org/10.1109/colcomcon.2019.8809113
# 111  [0302-9743, 1611-3349]    http://dx.doi.org/10.1007/978-3-030-35888-4_56
# 110  [1875-4791, 1875-4805]      http://dx.doi.org/10.1007/s12369-019-00609-9
# 108  [2194-5357, 2194-5365]    http://dx.doi.org/10.1007/978-3-319-78452-6_11
# 106             [2573-9522]                 http://dx.doi.org/10.1145/3366422
# 103  [1861-2776, 1861-2784]       http://dx.doi.org/10.1007/s11370-018-0266-9
#
#                                           abstractNote            accessDate  \
# 0    We report on a follow-up study of the Co-Write...  2020-03-30T00:08:16Z
# 119  Both storytelling and learning by teaching app...
# 118  It has been suggested that some individuals ma...
# 117  We conducted a study with 25 children to inves...            2020-03-18
# 115  According to the UNESCO, the sensitive periods...
# 111  We report on the exploratory design and study ...
# 110  This paper presents a sign recognition system ...  2020-03-16T06:23:39Z
# 108  In recent years, social robots are playing a v...
# 106  Social robots are increasingly applied to supp...  2020-03-17T06:24:09Z
# 103  In this paper, we present a novel dual-robot t...  2020-03-17T22:18:42Z
#
#     archive archiveLocation  \
# 0
# 119
# 118
# 117
# 115
# 111
# 110
# 108
# 106
# 103
#
#                                                 author bookTitle  ...  \
# 0    [{'given': 'Christia', 'family': 'Ioannou', 's...       NaN  ...
# 119  [{'given': 'Gijs', 'family': 'Verhoeven', 'seq...       NaN  ...
# 118  [{'given': 'Junko', 'family': 'Kanero', 'seque...       NaN  ...
# 117  [{'given': 'Christopher D.', 'family': 'Wallbr...       NaN  ...
# 115  [{'given': 'V.', 'family': 'Robles-Bykbaev', '...       NaN  ...
# 111  [{'given': 'Koen V.', 'family': 'Hindriks', 's...       NaN  ...
# 110  [{'given': 'Cemal', 'family': 'Gürpınar', 'seq...       NaN  ...
# 108  [{'given': 'Siva Leela Krishna Chand', 'family...       NaN  ...
# 106  [{'given': 'Thorsten', 'family': 'Schodde', 's...       NaN  ...
# 103  [{'ORCID': 'http://orcid.org/0000-0003-2851-55...       NaN  ...
#
#     Coded by Curriculum  Location Context\n nb students per robot  \
# 0        NaN        NaN       NaN       NaN                   NaN
# 119      NaN        NaN       NaN       NaN                   NaN
# 118      NaN        NaN       NaN       NaN                   NaN
# 117      NaN        NaN       NaN       NaN                   NaN
# 115      NaN        NaN       NaN       NaN                   NaN
# 111      NaN        NaN       NaN       NaN                   NaN
# 110      NaN        NaN       NaN       NaN                   NaN
# 108      NaN        NaN       NaN       NaN                   NaN
# 106      NaN        NaN       NaN       NaN                   NaN
# 103      NaN        NaN       NaN       NaN                   NaN
#
#     Communicative gestures vs functional actions Autonomy  \
# 0                                            NaN      NaN
# 119                                          NaN      NaN
# 118                                          NaN      NaN
# 117                                          NaN      NaN
# 115                                          NaN      NaN
# 111                                          NaN      NaN
# 110                                          NaN      NaN
# 108                                          NaN      NaN
# 106                                          NaN      NaN
# 103                                          NaN      NaN
#
#     Contain Retain component? Material Updated by
# 0                         NaN      NaN        NaN
# 119                       NaN      NaN        NaN
# 118                       NaN      NaN        NaN
# 117                       NaN      NaN        NaN
# 115                       NaN      NaN        NaN
# 111                       NaN      NaN        NaN
# 110                       NaN      NaN        NaN
# 108                       NaN      NaN        NaN
# 106                       NaN      NaN        NaN
# 103                       NaN      NaN        NaN
#
# [10 rows x 144 columns]

# %%
llllllljnjjji8ixfds
