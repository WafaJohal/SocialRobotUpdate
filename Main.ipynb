# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('social_robot4learning.xlsx', sheet_name = 'Sheet1')
data.head()
# Out:
#                                                title subtitle  \
# 0  Comparative study of effects of language instr...       []
# 1        Remote Education Based on Robot Edutainment       []
# 2  Comparative Study on the Educational Use of Ho...       []
# 3  A Robot as a Teaching Assistant in an English ...       []
# 4                                                NaN      NaN
#
#                                               author  \
# 0  [{'family': 'Eun-ja Hyun', 'sequence': 'first'...
# 1  [{'given': 'Akihiro', 'family': 'Yorita', 'seq...
# 2  [{'given': 'Jeong-Hye', 'family': 'Han', 'sequ...
# 3  [{'family': 'Zhen-Jia You', 'sequence': 'first...
# 4                                                NaN
#
#                              DOI                            ISBN      wtype  \
# 0     10.1109/roman.2008.4600664                   9781424422128  2004-2009
# 1   10.1007/978-3-642-03986-7_24  9783642039850', '9783642039867  2004-2009
# ...

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="wtype", data=data, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
                                              '2015', '2016', '2017', '2018', '2019', '2020'], palette="plasma")

# %% [markdown]
# ## Papers per country

# %%
data.Country.unique()
# Out:
# array(['South Korea', 'Japan', 'Taiwan', 'The Netherlands', 'USA',
#        'Turkey', 'Israel', 'Denmark', 'Sweden', 'Italy', 'Iran', 'UK',
#        'Singapore', 'Spain', 'Portugal', 'Switzerland', 'Germany',
#        'Ecuador', 'Greece', 'China', 'Finland', 'Pakistan', 'Kazakhstan'],
#       dtype=object)

# %%
df_plot = data.groupby(['wtype', 'Country']).size().reset_index().pivot(columns='Country', index='wtype', values=0)
df_plot.plot(kind='bar', stacked=True, cmap='tab20b')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# ## Robot Used

# %%
data['Robot/s used (?)'].unique()
# Out:
# array(['iRobiQ', 'SAYA/MOBiMacs', 'IROBI', 'Robosapien', 'Robotive',
#        'iCat', 'HOAP-3', 'Mero/Engkey', 'KTX-PC ', 'Bandit', 'Nao',
#        'SAYA', 'ROBOSEM', 'Wakamaru', 'Robovie/Lego', 'Geminoid',
#        'Darwin', 'Keepon', 'Robovie', 'Nao/Robovie', 'Nao torso', 'Meka',
#        'DragonBot', 'R3', 'LEGO', 'MantaroBot Classic', 'Lego', 'ifbot',
#        'EMYS', 'Tega', 'Robothespian', 'Bioloid', 'Repiro',
#        'stuffed toy robot', 'Maki', 'Pepper', nan, 'Jibo',
#        'Einstein Hanson', 'Minnie', 'Zeno', 'SPRITE', 'InMoov',
#        'WittyWorxk', 'IRI', 'Sota', 'instruMentor', 'CommU',
#        'SocibotMini', 'Haru', 'Furhat', 'MecWilly/Bluebot'], dtype=object)

# %%
df_plot = data.groupby(['Robot/s used (?)', 'wtype']).size().reset_index().pivot(columns='Robot/s used (?)', index='wtype', values=0)
df_plot.plot(kind='bar', stacked=True, cmap='tab20b')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Demographics for participants to studies

# %%
df_plot = data.groupby(['Adult vs Children', 'wtype']).size().reset_index().pivot(columns='Adult vs Children', index='wtype', values=0)
df_plot.plot(kind='bar', stacked=True, cmap='plasma')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Robot's Role
# 'Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)'

# %%
df_plot = data.groupby(['Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)', 
                             'wtype']).size().reset_index().pivot(columns='Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='plasma')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Curricular activity

# %%
df_plot = data.groupby(['Curriculum', 
                             'wtype']).size().reset_index().pivot(columns='Curriculum', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='tab20b')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Nb of students per robots *
#
# *Number of students concurrently interacting with the robot

# %%
df_plot = data.groupby(['students_nb', 
                             'wtype']).size().reset_index().pivot(columns='students_nb', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('plasma', 4))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Communicative gestures vs functional actions *
#
# *Communicative gestures refer to expressive motions, as the opposite of motions that are associated to manipulation of an object of displacement in space, here coded as functional actions. We also coded specifically Diectic gestures as D.

# %%
df_plot = data.groupby(['Communicative gestures vs functional actions', 
                             'wtype']).size().reset_index().pivot(columns='Communicative gestures vs functional actions', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('plasma', 4))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Retention *
#
# 'Yes' if the study contains a retention test.

# %%
df_plot = data.groupby(['Contain Retention component?', 
                             'wtype']).size().reset_index().pivot(columns='Contain Retention component?', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu',2))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Autonomy *
#
# Basic level of autonomy (couldn't be coded in detail as this information is often missing from empirical papers)

# %%
df_plot = data.groupby(['WoZ', 
                             'wtype']).size().reset_index().pivot(columns='WoZ', index='wtype', values=0)
df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 2))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Material *
# Describe which material is used in additon to the robot
# We proposed to code for :
# - PC
# - Tangibles (cubes, balance beam etc.)
# - Screen
# - Tablet
#
# some papers combine the material

# %%
df_plot = data.groupby(['Matos', 
                             'wtype']).size().reset_index().pivot(columns='Matos', index='wtype', values=0)
df_plot[['-', 'tangible(s)', 'tangible(s)+screen', 'tangible(s)+tablet', 'PC', 'PC+tangible(s)', 'screen', 'screen+tablet', 'tablet']].plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 9))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Publication Venue
#
# These data were obtained using Crossref library called !(habanero)[https://github.com/sckott/habanero]
# We parsed the crossref info of each publicaion based on their DOI

# %%
df_plot = data.groupby(['Field', 'wtype']).size().reset_index().pivot(columns='Field', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='plasma')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # Human-likeness

# %%
hl = pd.DataFrame()

hl['Robots'] = data["Robot/s used (?)"].unique()
hl['Human-likeliness'] = 0
hl['Facial Features'] = 0
hl['Body Manipulators'] = 0
hl['Surface Look'] = 0

# %%
hl.to_csv('Robots_ABOT_HumanLikeness.csv', index=False, sep=';')
