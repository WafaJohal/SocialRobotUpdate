# %%
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_excel('social_robot4learning.xlsx', sheet_name = 'Sheet1')
data
# Out:
#     Adult vs Children             Autonomy  \
# 0                  Ch             Scripted
# 1                  Ch                  NaN
# 2                  Ch             Scripted
# 3                  Ch             Scripted
# 4                  Ch           autonomous
# ..                ...                  ...
# 155                Ad             scripted
# 156                Ad  semi-autonomous WOZ
# 157                Ch             Scripted
# 158                Ch             scripted
# 159                Ch           autonomous
#
#     Communicative gestures vs functional actions Contain Retention component?  \
# 0                                             CO                           No
# 1                                             CO                          Yes
# 2                                             CO                           No
# 3                                             CO                           No
# 4                                             CO                           No
# ..                                           ...                          ...
# 155                                           CO                           No
# 156                                           CO                          NaN
# 157                                        CO+FU                           No
# 158                                           CO                           No
# 159                                           CO                          Yes
#
#          Country       Curriculum                            DOI  \
# 0    South Korea               L2     10.1109/roman.2008.4600664
# 1          Japan              NaN   10.1007/978-3-642-03986-7_24
# 2    South Korea               L2      10.3745/jips.2008.4.4.159
# 3         Taiwan               L2     10.1109/icalt.2006.1652373
# 4          Japan               L2  10.1080/07370024.2004.9667340
# ..           ...              ...                            ...
# 155        Japan             math     10.20965/jaciii.2020.p0101
# 156       Sweden               L2     10.1007/s12369-020-00635-y
# 157       Greece      handwriting       10.21125/inted.2020.1926
# 158        Italy  problem solving             10.1111/bjet.12848
# 159          USA       vocabulary  10.1016/j.compedu.2020.103836
#
#                                    ISBN Included     Material  ...  \
# 0                     ['9781424422128']      Yes         book  ...
# 1    ['9783642039850', '9783642039867']      Yes        cards  ...
# 2                                   NaN      Yes            -  ...
# 3                        ['0769526322']      Yes            -  ...
# 4                                   NaN      Yes            -  ...
# ..                                  ...      ...          ...  ...
# 155                                 NaN      Yes  PC+tangible  ...
# 156                                 NaN      Yes            -  ...
# 157                   ['9788409179398']      Yes       tablet  ...
# 158                                 NaN      Yes            -  ...
# 159                                 NaN      Yes       tablet  ...
#
#                       published-print  \
# 0         {'date-parts': [[2008, 8]]}
# 1            {'date-parts': [[2009]]}
# 2    {'date-parts': [[2008, 12, 31]]}
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 155   {'date-parts': [[2020, 1, 20]]}
# 156                               NaN
# 157       {'date-parts': [[2020, 3]]}
# 158       {'date-parts': [[2020, 3]]}
# 159       {'date-parts': [[2020, 6]]}
#
#                                    publisher reference-count references-count  \
# 0                                       IEEE            13.0             13.0
# 1                 Springer Berlin Heidelberg            19.0             19.0
# 2       Korea Information Processing Society             6.0              6.0
# 3                                       IEEE            11.0             11.0
# 4                                        NaN             NaN              NaN
# ..                                       ...             ...              ...
# 155               Fuji Technology Press Ltd.            22.0             22.0
# 156  Springer Science and Business Media LLC            42.0             42.0
# 157                                    IATED             0.0              0.0
# 158                                    Wiley            40.0             40.0
# 159                              Elsevier BV            80.0             80.0
#
#     students_nb subtitle                                              title  \
# 0             1       []  ['Comparative study of effects of language ins...
# 1             1       []    ['Remote Education Based on Robot Edutainment']
# 2             1       []  ['Comparative Study on the Educational Use of ...
# 3         class       []  ['A Robot as a Teaching Assistant in an Englis...
# 4         small      NaN                                                NaN
# ..          ...      ...                                                ...
# 155           1       []  ['Learning Effects of Robots Teaching Based on...
# 156        pair       []  ['Robot Interaction Styles for Conversation Pr...
# 157           1       []  ['LEARNING (GOOD HANDWRITING IN GREEK) BY TEAC...
# 158        pair       []  ['Enhancing wayfinding in pre‐school children ...
# 159           1       []  ['Teaching and learning with children: Impact ...
#
#                     type      wtype  \
# 0    proceedings-article  2004-2009
# 1           book-chapter  2004-2009
# 2        journal-article  2004-2009
# 3    proceedings-article  2004-2009
# 4                    NaN  2004-2009
# ..                   ...        ...
# 155      journal-article       2020
# 156      journal-article       2020
# 157  proceedings-article       2020
# 158      journal-article       2020
# 159      journal-article       2020
#
#                                                   link
# 0    [{'URL': 'http://xplorestaging.ieee.org/ielx5/...
# 1    [{'URL': 'http://link.springer.com/content/pdf...
# 2    [{'URL': 'http://ocean.kisti.re.kr/downfile/cr...
# 3    [{'URL': 'http://xplorestaging.ieee.org/ielx5/...
# 4                                                  NaN
# ..                                                 ...
# 155  [{'URL': 'https://www.fujipress.jp/main/wp-con...
# 156  [{'URL': 'http://link.springer.com/content/pdf...
# 157                                                NaN
# 158  [{'URL': 'https://onlinelibrary.wiley.com/doi/...
# 159  [{'URL': 'https://api.elsevier.com/content/art...
#
# [160 rows x 32 columns]

# %%
data_anno = data_anno[data_anno.Included == 'Yes']
data_anno
# Out:
#                                DOI          Country Robot/s used (?)  \
# 0         10.21125/inted.2020.1926           Greece              Nao
# 1         10.3389/frobt.2020.00015            Spain             Haru
# 2         10.3389/frobt.2019.00148           Israel              Nao
# 3          10.1145/3319502.3374822              USA             Tega
# 4          10.1145/3319502.3374803  The Netherlands             Zeno
# ..                             ...              ...              ...
# 187     10.1109/icalt.2006.1652373           Taiwan       Robosapien
# 188     10.1109/roman.2008.4600664      South Korea           iRobiQ
# 189   10.1007/978-3-642-03986-7_24            Japan    SAYA/MOBiMacs
# 190      10.3745/jips.2008.4.4.159      South Korea            IROBI
# 191  10.1080/07370024.2004.9667340            Japan         Robotive
#
#     Adult vs Children      wtype  \
# 0                  Ch       2020
# 1                  Ch       2020
# 2                  Ad       2020
# 3                  Ch       2020
# 4                  Ch       2020
# ..                ...        ...
# 187                Ch  2004-2009
# 188                Ch  2004-2009
# 189                Ch  2004-2009
# 190                Ch  2004-2009
# 191                Ch  2004-2009
#
#     Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)  \
# 0                                                   Pe
# 1                                                   Tu
# 2                                                   Te
# 3                                                   Tu
# 4                                                   Tu
# ..                                                 ...
# 187                                                 Te
# 188                                                 Te
# 189                                                 Te
# 190                                                 Te
# 191                                              Pe/Tu
#
#           Curriculum nb students per robot students_nb  \
# 0        handwriting                     1           1
# 1    problem solving                     1           1
# 2                HCI                     3       small
# 3         Vocabulary                     1           1
# 4    problem solving                     1           1
# ..               ...                   ...         ...
# 187               L2                    33       class
# 188               L2                     1           1
# 189              NaN                     1           1
# 190               L2                     1           1
# 191               L2              variable       small
#
#     Communicative gestures vs functional actions  WoZ    Autonomy  \
# 0                                          CO+FU   No    Scripted
# 1                                             CO  Yes         WOZ
# 2                                             CO   No    Scripted
# 3                                             CO   No    Scripted
# 4                                             CO   No    Scripted
# ..                                           ...  ...         ...
# 187                                           CO   No    Scripted
# 188                                           CO   No    Scripted
# 189                                           CO  NaN         NaN
# 190                                           CO   No    Scripted
# 191                                           CO   No  autonomous
#
#     Contain Retention component?               Matos         Material Included
# 0                             No              tablet           tablet      Yes
# 1                             No         tangible(s)        tangibles      Yes
# 2                             No              tablet           tablet      Yes
# 3                             No              tablet           tablet      Yes
# 4                             No  tangible(s)+tablet  tablet+tangible      Yes
# ..                           ...                 ...              ...      ...
# 187                           No                   -                -      Yes
# 188                           No         tangible(s)             book      Yes
# 189                          Yes         tangible(s)            cards      Yes
# 190                           No                   -                -      Yes
# 191                           No                   -                -      Yes
#
# [160 rows x 16 columns]

# %%
cols = ['mean', 0L, 1L, 2L, 3L, 4L]

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="wtype", data=data_anno, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
                                              '2015', '2016', '2017', '2018', '2019', '2020'], palette="husl")
# Out:
# <div id='854b0a2a-3747-4b16-865e-6ad0af583a96'></div>

# %% [markdown]
# ## Papers per country

# %%
data_anno.Country.unique()
# Out:
# array(['Greece', 'Spain', 'Israel', 'USA', 'The Netherlands', 'Japan',
#        'Sweden', 'Italy', 'Kazakhstan', 'Germany', 'Iran', 'UK', 'Turkey',
#        'Denmark', 'Portugal', 'Finland', 'Pakistan', 'Ecuador', 'China',
#        'Switzerland', 'Taiwan', 'Singapore', 'South Korea'], dtype=object)

# %%
data_anno
# Out:
#                                DOI          Country Robot/s used (?)  \
# 0         10.21125/inted.2020.1926           Greece              Nao
# 1         10.3389/frobt.2020.00015            Spain             Haru
# 2         10.3389/frobt.2019.00148           Israel              Nao
# 3          10.1145/3319502.3374822              USA             Tega
# 4          10.1145/3319502.3374803  The Netherlands             Zeno
# ..                             ...              ...              ...
# 187     10.1109/icalt.2006.1652373           Taiwan       Robosapien
# 188     10.1109/roman.2008.4600664      South Korea           iRobiQ
# 189   10.1007/978-3-642-03986-7_24            Japan    SAYA/MOBiMacs
# 190      10.3745/jips.2008.4.4.159      South Korea            IROBI
# 191  10.1080/07370024.2004.9667340            Japan         Robotive
#
#     Adult vs Children      wtype  \
# 0                  Ch       2020
# 1                  Ch       2020
# 2                  Ad       2020
# 3                  Ch       2020
# 4                  Ch       2020
# ..                ...        ...
# 187                Ch  2004-2009
# 188                Ch  2004-2009
# 189                Ch  2004-2009
# 190                Ch  2004-2009
# 191                Ch  2004-2009
#
#     Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)  \
# 0                                                   Pe
# 1                                                   Tu
# 2                                                   Te
# 3                                                   Tu
# 4                                                   Tu
# ..                                                 ...
# 187                                                 Te
# 188                                                 Te
# 189                                                 Te
# 190                                                 Te
# 191                                              Pe/Tu
#
#           Curriculum nb students per robot students_nb  \
# 0        handwriting                     1           1
# 1    problem solving                     1           1
# 2                HCI                     3       small
# 3         Vocabulary                     1           1
# 4    problem solving                     1           1
# ..               ...                   ...         ...
# 187               L2                    33       class
# 188               L2                     1           1
# 189              NaN                     1           1
# 190               L2                     1           1
# 191               L2              variable       small
#
#     Communicative gestures vs functional actions  WoZ    Autonomy  \
# 0                                          CO+FU   No    Scripted
# 1                                             CO  Yes         WOZ
# 2                                             CO   No    Scripted
# 3                                             CO   No    Scripted
# 4                                             CO   No    Scripted
# ..                                           ...  ...         ...
# 187                                           CO   No    Scripted
# 188                                           CO   No    Scripted
# 189                                           CO  NaN         NaN
# 190                                           CO   No    Scripted
# 191                                           CO   No  autonomous
#
#     Contain Retention component?               Matos         Material Included
# 0                             No              tablet           tablet      Yes
# 1                             No         tangible(s)        tangibles      Yes
# 2                             No              tablet           tablet      Yes
# 3                             No              tablet           tablet      Yes
# 4                             No  tangible(s)+tablet  tablet+tangible      Yes
# ..                           ...                 ...              ...      ...
# 187                           No                   -                -      Yes
# 188                           No         tangible(s)             book      Yes
# 189                          Yes         tangible(s)            cards      Yes
# 190                           No                   -                -      Yes
# 191                           No                   -                -      Yes
#
# [160 rows x 16 columns]

# %%
df_plot = data_anno.groupby(['wtype', 'Country']).size().reset_index().pivot(columns='Country', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='tab20b').savefig("test.svg")


#plt.figure(figsize=(20,10))
#ax = sns.countplot(x="wtype", data=data_anno, order=['2004-2009','2010', '2011', '2012', '2013', '2014', 
#                                                  '2015', '2016', '2017', '2018', '2019', '2020'], hue=data_anno.Country)

df_plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-7cb8fcb38df2> in <module>
#       9
#      10
# ---> 11 df_plot.savefig("test.svg")
#
# ~/.cache/pypoetry/virtualenvs/socialrobotupdate-NZ4rEjTX-py3.8/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'savefig'

# %% [markdown]
# ## Robot Used

# %%
data_anno['Robot/s used (?)'].unique()
# Out:
# array(['Nao', 'Haru', 'Tega', 'Zeno', 'Sota', 'Furhat',
#        'MecWilly/Bluebot', 'SocibotMini', 'DragonBot', 'Repiro',
#        'Wakamaru', 'Keepon', 'Robotive', 'Nao/Robovie', 'Robovie',
#        'Nao torso', 'Bandit', 'Darwin', 'Robovie/Lego', 'Geminoid',
#        'Pepper', 'IRI', 'SPRITE', 'WittyWorxk', 'Jibo', 'InMoov',
#        'instruMentor', 'CommU', 'stuffed toy robot', nan,
#        'Einstein Hanson', 'Minnie', 'Maki', 'Bioloid', 'EMYS', 'ifbot',
#        'MantaroBot Classic', 'Lego', 'Robothespian', 'Meka', 'R3', 'LEGO',
#        'KTX-PC ', 'ROBOSEM', 'SAYA', 'Mero/Engkey', 'iCat', 'HOAP-3',
#        'Robosapien', 'iRobiQ', 'SAYA/MOBiMacs', 'IROBI'], dtype=object)

# %%
df_plot = data_anno.groupby(['Robot/s used (?)', 'wtype']).size().reset_index().pivot(columns='Robot/s used (?)', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='tab20b')

# %%
df_plot = data_anno.groupby(['Adult vs Children', 'wtype']).size().reset_index().pivot(columns='Adult vs Children', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='plasma')

# %% [markdown]
# ## Roles
# 'Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)'

# %%
df_plot = data_anno.groupby(['Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)', 
                             'wtype']).size().reset_index().pivot(columns='Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='plasma')

# %% [markdown]
# ## Curriculum

# %%
df_plot = data_anno.groupby(['Curriculum', 
                             'wtype']).size().reset_index().pivot(columns='Curriculum', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap='plasma')

# %% [markdown]
# ## Nb of students per robots *

# %%
df_plot = data_anno.groupby(['students_nb', 
                             'wtype']).size().reset_index().pivot(columns='students_nb', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 4))

# %% [markdown]
# ## Communicative gestures vs functional actions *

# %%
df_plot = data_anno.groupby(['Communicative gestures vs functional actions', 
                             'wtype']).size().reset_index().pivot(columns='Communicative gestures vs functional actions', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 4))

# %% [markdown]
# ## Retention *
# Contain Retention component?

# %%
df_plot = data_anno.groupby(['Contain Retention component?', 
                             'wtype']).size().reset_index().pivot(columns='Contain Retention component?', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 2))

# %% [markdown]
# ## Autonomy *

# %%
df_plot = data_anno.groupby(['WoZ', 
                             'wtype']).size().reset_index().pivot(columns='WoZ', index='wtype', values=0)

df_plot.plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 2))

# %% [markdown]
# ## Material *

# %%
df_plot = data_anno.groupby(['Matos', 
                             'wtype']).size().reset_index().pivot(columns='Matos', index='wtype', values=0)

df_plot.columns
# Out:
# Index(['-', 'PC', 'PC+tangible(s)', 'screen', 'screen+tablet', 'tablet',
#        'tangible(s)', 'tangible(s)+screen', 'tangible(s)+tablet'],
#       dtype='object', name='Matos')

# %%
df_plot[['-', 'tangible(s)', 'tangible(s)+screen', 'tangible(s)+tablet', 'PC', 'PC+tangible(s)', 'screen', 'screen+tablet', 'tablet']].plot(kind='bar', stacked=True, cmap=plt.cm.get_cmap('RdBu', 9))

# %% [markdown]
# # Human-likeness

# %%
hl = pd.DataFrame()

hl['Robots'] = data_anno["Robot/s used (?)"].unique()
hl['Human-likeliness'] = 0
hl['Facial Features'] = 0
hl['Body Manipulators'] = 0
hl['Surface Look'] = 0

# %%
hl.to_csv('Robots_ABOT_HumanLikeness.csv', index=False, sep=';')

# %% [markdown]
# # Publication Venue

# %%
cr = Crossref()

# %%
cr_df = pd.DataFrame()
for p in range(len(data_anno)): 
    print(data_anno.loc[p])
    if(data_anno.at[p,'DOI'] !='' and data_anno.at[p,'DOI'] !='nan'):
        print(data_anno.at[p,'DOI'])
        try:
            jsdata = cr.works(ids=[data_anno.at[p,'DOI']])
            print('got data')
        except:
            print(data_anno.at[p,'title'], data_anno.at[p,'DOI'])
            print("Query failed")
            r = dict(data_anno.loc[p])
            cr_df = cr_df.append(r, ignore_index = True)
            continue
        print('parsing ...')
        if (jsdata['status'] == 'ok'):
            r = dict(data_anno.loc[p])
            r.update(jsdata['message'])
            cr_df = cr_df.append(r, ignore_index = True)
        print('done-------------------------------')
        
        
    else:
        print(df.loc[p])
# Out:
# DOI                                                                                    10.21125/inted.2020.1926
# Country                                                                                                  Greece
# Robot/s used (?)                                                                                            Nao
# Adult vs Children                                                                                            Ch
# wtype                                                                                                      2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                          Pe
# Curriculum                                                                                          handwriting
# nb students per robot                                                                                         1
# students_nb                                                                                                   1
# Communicative gestures vs functional actions                                                              CO+FU
# WoZ                                                                                                          No
# Autonomy                                                                                               Scripted
# Contain Retention component?                                                                                 No
# Matos                                                                                                    tablet
# Material                                                                                                 tablet
# Included                                                                                                    Yes
# Name: 0, dtype: object
# 10.21125/inted.2020.1926
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.3389/frobt.2020.00015
# Country                                                                                                   Spain
# Robot/s used (?)                                                                                           Haru
# Adult vs Children                                                                                            Ch
# wtype                                                                                                      2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                          Tu
# Curriculum                                                                                      problem solving
# nb students per robot                                                                                         1
# students_nb                                                                                                   1
# Communicative gestures vs functional actions                                                                 CO
# WoZ                                                                                                         Yes
# Autonomy                                                                                                    WOZ
# Contain Retention component?                                                                                 No
# Matos                                                                                               tangible(s)
# Material                                                                                              tangibles
# Included                                                                                                    Yes
# Name: 1, dtype: object
# 10.3389/frobt.2020.00015
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.3389/frobt.2019.00148
# Country                                                                                                  Israel
# Robot/s used (?)                                                                                            Nao
# Adult vs Children                                                                                            Ad
# wtype                                                                                                      2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                          Te
# Curriculum                                                                                                  HCI
# nb students per robot                                                                                         3
# students_nb                                                                                               small
# Communicative gestures vs functional actions                                                                 CO
# WoZ                                                                                                          No
# Autonomy                                                                                               Scripted
# Contain Retention component?                                                                                 No
# Matos                                                                                                    tablet
# Material                                                                                                 tablet
# Included                                                                                                    Yes
# Name: 2, dtype: object
# 10.3389/frobt.2019.00148
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374822
# Country                                                                                                    USA
# Robot/s used (?)                                                                                          Tega
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                          Vocabulary
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                              Scripted
# Contain Retention component?                                                                                No
# Matos                                                                                                   tablet
# Material                                                                                                tablet
# Included                                                                                                   Yes
# Name: 3, dtype: object
# 10.1145/3319502.3374822
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374803
# Country                                                                                        The Netherlands
# Robot/s used (?)                                                                                          Zeno
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                     problem solving
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                              Scripted
# Contain Retention component?                                                                                No
# Matos                                                                                       tangible(s)+tablet
# Material                                                                                       tablet+tangible
# Included                                                                                                   Yes
# Name: 4, dtype: object
# 10.1145/3319502.3374803
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374828
# Country                                                                                        The Netherlands
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                                  L2
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                              Scripted
# Contain Retention component?                                                                                No
# Matos                                                                                                   tablet
# Material                                                                                                tablet
# Included                                                                                                   Yes
# Name: 5, dtype: object
# 10.1145/3319502.3374828
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.20965/jaciii.2020.p0101
# Country                                                                                                     Japan
# Robot/s used (?)                                                                                             Sota
# Adult vs Children                                                                                              Ad
# wtype                                                                                                        2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                            Tu
# Curriculum                                                                                                   math
# nb students per robot                                                                                           1
# students_nb                                                                                                     1
# Communicative gestures vs functional actions                                                                   CO
# WoZ                                                                                                            No
# Autonomy                                                                                                 scripted
# Contain Retention component?                                                                                   No
# Matos                                                                                              PC+tangible(s)
# Material                                                                                              PC+tangible
# Included                                                                                                      Yes
# Name: 6, dtype: object
# 10.20965/jaciii.2020.p0101
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/s12369-020-00635-y
# Country                                                                                                    Sweden
# Robot/s used (?)                                                                                           Furhat
# Adult vs Children                                                                                              Ad
# wtype                                                                                                        2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Pe/Tu
# Curriculum                                                                                                     L2
# nb students per robot                                                                                           2
# students_nb                                                                                                  pair
# Communicative gestures vs functional actions                                                                   CO
# WoZ                                                                                                           Yes
# Autonomy                                                                                      semi-autonomous WOZ
# Contain Retention component?                                                                                  NaN
# Matos                                                                                                           -
# Material                                                                                                        -
# Included                                                                                                      Yes
# Name: 7, dtype: object
# 10.1007/s12369-020-00635-y
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1111/bjet.12848
# Country                                                                                             Italy
# Robot/s used (?)                                                                         MecWilly/Bluebot
# Adult vs Children                                                                                      Ch
# wtype                                                                                                2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                    Tu
# Curriculum                                                                                problem solving
# nb students per robot                                                                              1 or 2
# students_nb                                                                                          pair
# Communicative gestures vs functional actions                                                           CO
# WoZ                                                                                                    No
# Autonomy                                                                                         scripted
# Contain Retention component?                                                                           No
# Matos                                                                                                   -
# Material                                                                                                -
# Included                                                                                              Yes
# Name: 8, dtype: object
# 10.1111/bjet.12848
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374787
# Country                                                                                        The Netherlands
# Robot/s used (?)                                                                                   SocibotMini
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                               Music
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                        Yes
# Autonomy                                                                                                   WoZ
# Contain Retention component?                                                                                No
# Matos                                                                                                        -
# Material                                                                                                     -
# Included                                                                                                   Yes
# Name: 9, dtype: object
# 10.1145/3319502.3374787
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374813
# Country                                                                                             Kazakhstan
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Pe
# Curriculum                                                                                         handwriting
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                             CO+FU
# WoZ                                                                                                         No
# Autonomy                                                                                       semi-autonomous
# Contain Retention component?                                                                                No
# Matos                                                                                                   tablet
# Material                                                                                                tablet
# Included                                                                                                   Yes
# Name: 10, dtype: object
# 10.1145/3319502.3374813
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374826
# Country                                                                                        The Netherlands
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                      Pe/Tu
# Curriculum                                                                                        storytelling
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                              scripted
# Contain Retention component?                                                                                No
# Matos                                                                                                        -
# Material                                                                                                     -
# Included                                                                                                   Yes
# Name: 11, dtype: object
# 10.1145/3319502.3374826
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/3319502.3374815
# Country                                                                                        The Netherlands
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ch
# wtype                                                                                                     2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                                  L2
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                              scripted
# Contain Retention component?                                                                               Yes
# Matos                                                                                                   tablet
# Material                                                                                                tablet
# Included                                                                                                   Yes
# Name: 12, dtype: object
# 10.1145/3319502.3374815
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1016/j.compedu.2020.103836
# Country                                                                                                          USA
# Robot/s used (?)                                                                                                Tega
# Adult vs Children                                                                                                 Ch
# wtype                                                                                                           2020
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                            Pe/Tu
# Curriculum                                                                                                vocabulary
# nb students per robot                                                                                              1
# students_nb                                                                                                        1
# Communicative gestures vs functional actions                                                                      CO
# WoZ                                                                                                               No
# Autonomy                                                                                                  autonomous
# Contain Retention component?                                                                                     Yes
# Matos                                                                                                         tablet
# Material                                                                                                      tablet
# Included                                                                                                         Yes
# Name: 13, dtype: object
# 10.1016/j.compedu.2020.103836
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1016/j.ijcci.2017.04.001
# Country                                                                                                        USA
# Robot/s used (?)                                                                                         DragonBot
# Adult vs Children                                                                                               Ch
# wtype                                                                                                         2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                             Tu
# Curriculum                                                                                              vocabulary
# nb students per robot                                                                                            1
# students_nb                                                                                                      1
# Communicative gestures vs functional actions                                                                    CO
# WoZ                                                                                                            Yes
# Autonomy                                                                                                       Woz
# Contain Retention component?                                                                                    No
# Matos                                                                                                       tablet
# Material                                                                                                    tablet
# Included                                                                                                       Yes
# Name: 14, dtype: object
# 10.1016/j.ijcci.2017.04.001
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/2909824.3020242
# Country                                                                                                Germany
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ad
# wtype                                                                                                     2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                            multiple
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                        Yes
# Autonomy                                                                                                   Woz
# Contain Retention component?                                                                                No
# Matos                                                                                                       PC
# Material                                                                                                    PC
# Included                                                                                                   Yes
# Name: 15, dtype: object
# 10.1145/2909824.3020242
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/978-3-319-70022-9_25
# Country                                                                                                        Iran
# Robot/s used (?)                                                                                                Nao
# Adult vs Children                                                                                                Ch
# wtype                                                                                                          2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                              Tu
# Curriculum                                                                                                       L2
# nb students per robot                                                                                             1
# students_nb                                                                                                       1
# Communicative gestures vs functional actions                                                                     CO
# WoZ                                                                                                              No
# Autonomy                                                                                                   Scripted
# Contain Retention component?                                                                                     No
# Matos                                                                                                             -
# Material                                                                                                          -
# Included                                                                                                        Yes
# Name: 16, dtype: object
# 10.1007/978-3-319-70022-9_25
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/s12369-017-0430-y
# Country                                                                                                       UK
# Robot/s used (?)                                                                                             Nao
# Adult vs Children                                                                                             Ch
# wtype                                                                                                       2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                           Tu
# Curriculum                                                                                             geography
# nb students per robot                                                                                          1
# students_nb                                                                                                    1
# Communicative gestures vs functional actions                                                                CO+D
# WoZ                                                                                                           No
# Autonomy                                                                                              autonomous
# Contain Retention component?                                                                                  No
# Matos                                                                                                     tablet
# Material                                                                                                  tablet
# Included                                                                                                     Yes
# Name: 17, dtype: object
# 10.1007/s12369-017-0430-y
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1109/companion.2017.8287073
# Country                                                                                                       Germany
# Robot/s used (?)                                                                                                  Nao
# Adult vs Children                                                                                                  Ch
# wtype                                                                                                            2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                                Tu
# Curriculum                                                                                                         L2
# nb students per robot                                                                                               1
# students_nb                                                                                                         1
# Communicative gestures vs functional actions                                                                       CO
# WoZ                                                                                                                No
# Autonomy                                                                                                     scripted
# Contain Retention component?                                                                                       No
# Matos                                                                                                          tablet
# Material                                                                                                       tablet
# Included                                                                                                          Yes
# Name: 18, dtype: object
# 10.1109/companion.2017.8287073
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/2909824.3020222
# Country                                                                                                Germany
# Robot/s used (?)                                                                                           Nao
# Adult vs Children                                                                                           Ad
# wtype                                                                                                     2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                                  L2
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                         No
# Autonomy                                                                                            autonomous
# Contain Retention component?                                                                                No
# Matos                                                                                                   tablet
# Material                                                                                                tablet
# Included                                                                                                   Yes
# Name: 19, dtype: object
# 10.1145/2909824.3020222
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1109/roman.2017.8172341
# Country                                                                                           The Netherlands
# Robot/s used (?)                                                                                              Nao
# Adult vs Children                                                                                              Ch
# wtype                                                                                                        2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                            Te
# Curriculum                                                                                                 health
# nb students per robot                                                                                           1
# students_nb                                                                                                     1
# Communicative gestures vs functional actions                                                                   CO
# WoZ                                                                                                            No
# Autonomy                                                                                                  scipted
# Contain Retention component?                                                                                   No
# Matos                                                                                                      screen
# Material                                                                                                   screen
# Included                                                                                                      Yes
# Name: 20, dtype: object
# 10.1109/roman.2017.8172341
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/s10514-016-9598-5
# Country                                                                                                   Turkey
# Robot/s used (?)                                                                                             Nao
# Adult vs Children                                                                                             Ad
# wtype                                                                                                       2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                           Tu
# Curriculum                                                                                     physical exercise
# nb students per robot                                                                                          1
# students_nb                                                                                                    1
# Communicative gestures vs functional actions                                                               CO+FU
# WoZ                                                                                                           No
# Autonomy                                                                                              autonomous
# Contain Retention component?                                                                                  No
# Matos                                                                                                          -
# Material                                                                                                       -
# Included                                                                                                     Yes
# Name: 21, dtype: object
# 10.1007/s10514-016-9598-5
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/978-3-319-42975-5_23
# Country                                                                                             The Netherlands
# Robot/s used (?)                                                                                                Nao
# Adult vs Children                                                                                                Ch
# wtype                                                                                                          2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                              Pe
# Curriculum                                                                                            communication
# nb students per robot                                                                                             1
# students_nb                                                                                                       1
# Communicative gestures vs functional actions                                                                     CO
# WoZ                                                                                                             Yes
# Autonomy                                                                                                        WOZ
# Contain Retention component?                                                                                     No
# Matos                                                                                                            PC
# Material                                                                                                         PC
# Included                                                                                                        Yes
# Name: 22, dtype: object
# 10.1007/978-3-319-42975-5_23
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1299/mel.16-00471
# Country                                                                                               Japan
# Robot/s used (?)                                                                                     Repiro
# Adult vs Children                                                                                        Ch
# wtype                                                                                                  2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                      Ot
# Curriculum                                                                                   caring mindset
# nb students per robot                                                                               6-13-14
# students_nb                                                                                           class
# Communicative gestures vs functional actions                                                          CO+FU
# WoZ                                                                                                     Yes
# Autonomy                                                                                                WOZ
# Contain Retention component?                                                                             No
# Matos                                                                                                     -
# Material                                                                                                  -
# Included                                                                                                Yes
# Name: 23, dtype: object
# 10.1299/mel.16-00471
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/s12369-016-0378-3
# Country                                                                                                       UK
# Robot/s used (?)                                                                                             Nao
# Adult vs Children                                                                                             Ad
# wtype                                                                                                       2017
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                           Tu
# Curriculum                                                                                              literacy
# nb students per robot                                                                                        NaN
# students_nb                                                                                                  NaN
# Communicative gestures vs functional actions                                                                  CO
# WoZ                                                                                                           No
# Autonomy                                                                                                scripted
# Contain Retention component?                                                                                  No
# Matos                                                                                                          -
# Material                                                                                                       -
# Included                                                                                                     Yes
# Name: 24, dtype: object
# 10.1007/s12369-016-0378-3
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1016/j.cogsys.2016.08.003
# Country                                                                                             The Netherlands
# Robot/s used (?)                                                                                                Nao
# ...
# Contain Retention component?                                                                                  No
# Matos                                                                                                tangible(s)
# Material                                                                                                   cards
# Included                                                                                                     Yes
# Name: 36, dtype: object
# 10.1142/s0219843614500030
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1016/j.compedu.2013.07.043
# Country                                                                                                       Israel
# Robot/s used (?)                                                                                                 Nao
# Adult vs Children                                                                                                 Ch
# wtype                                                                                                           2014
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                               TA
# Curriculum                                                                                              storytelling
# nb students per robot                                                                                              5
# students_nb                                                                                                    small
# Communicative gestures vs functional actions                                                                      CO
# WoZ                                                                                                              Yes
# Autonomy                                                                                                 Woz+scrpted
# Contain Retention component?                                                                                     NaN
# Matos                                                                                                         screen
# Material                                                                                                      screen
# Included                                                                                                         Yes
# Name: 37, dtype: object
# 10.1016/j.compedu.2013.07.043
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1145/2559636.2559667
# Country                                                                                                  Japan
# Robot/s used (?)                                                                                       Robovie
# Adult vs Children                                                                                           Ad
# wtype                                                                                                     2014
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                      Tu/Te
# Curriculum                                                                                             biology
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                                CO
# WoZ                                                                                                        Yes
# Autonomy                                                                                                   WOZ
# Contain Retention component?                                                                                No
# Matos                                                                                                        -
# Material                                                                                                     -
# Included                                                                                                   Yes
# Name: 38, dtype: object
# 10.1145/2559636.2559667
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1007/978-3-319-11973-1_19
# Country                                                                                                          UK
# Robot/s used (?)                                                                                          Nao torso
# Adult vs Children                                                                                                Ch
# wtype                                                                                                          2014
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                              Tu
# Curriculum                                                                                                geography
# nb students per robot                                                                                             1
# students_nb                                                                                                       1
# Communicative gestures vs functional actions                                                                   CO+D
# WoZ                                                                                                              No
# Autonomy                                                                                                   scripted
# Contain Retention component?                                                                                     No
# Matos                                                                                                        tablet
# Material                                                                                                     tablet
# Included                                                                                                        Yes
# Name: 39, dtype: object
# 10.1007/978-3-319-11973-1_19
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1109/icrom.2014.6990994
# Country                                                                                                      Iran
# Robot/s used (?)                                                                                              Nao
# Adult vs Children                                                                                              Ch
# wtype                                                                                                        2014
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                            Te
# Curriculum                                                                                                     L2
# nb students per robot                                                                                          15
# students_nb                                                                                                 class
# Communicative gestures vs functional actions                                                                   CO
# WoZ                                                                                                            No
# Autonomy                                                                                                 scripted
# Contain Retention component?                                                                                   No
# Matos                                                                                                           -
# Material                                                                                                        -
# Included                                                                                                      Yes
# Name: 40, dtype: object
# 10.1109/icrom.2014.6990994
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1142/s0219843614500224
# Country                                                                                                     Iran
# Robot/s used (?)                                                                                             Nao
# Adult vs Children                                                                                             Ch
# wtype                                                                                                       2014
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                           Te
# Curriculum                                                                                                    L2
# nb students per robot                                                                                         15
# students_nb                                                                                                class
# Communicative gestures vs functional actions                                                                  CO
# WoZ                                                                                                           No
# Autonomy                                                                                                scripted
# Contain Retention component?                                                                                  No
# Matos                                                                                                          -
# Material                                                                                                       -
# Included                                                                                                     Yes
# Name: 41, dtype: object
# 10.1142/s0219843614500224
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.5898/jhri.2.2.fasola
# Country                                                                                                    USA
# Robot/s used (?)                                                                                        Bandit
# Adult vs Children                                                                                           Ad
# wtype                                                                                                     2013
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                         Tu
# Curriculum                                                                                   physical exercise
# nb students per robot                                                                                        1
# students_nb                                                                                                  1
# Communicative gestures vs functional actions                                                             CO+FU
# WoZ                                                                                                         No
# Autonomy                                                                                              ścripted
# Contain Retention component?                                                                                No
# Matos                                                                                                        -
# Material                                                                                                     -
# Included                                                                                                   Yes
# Name: 42, dtype: object
# 10.5898/jhri.2.2.fasola
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1109/humanoids.2013.7029974
# Country                                                                                                           USA
# Robot/s used (?)                                                                                               Darwin
# Adult vs Children                                                                                                  Ch
# wtype                                                                                                            2013
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                                Tu
# Curriculum                                                                                                       math
# nb students per robot                                                                                               1
# students_nb                                                                                                         1
# Communicative gestures vs functional actions                                                                       CO
# WoZ                                                                                                                No
# Autonomy                                                                                                     scripted
# Contain Retention component?                                                                                       No
# Matos                                                                                                          tablet
# Material                                                                                                       tablet
# Included                                                                                                          Yes
# Name: 43, dtype: object
# 10.1109/humanoids.2013.7029974
# got data
# parsing ...
# done-------------------------------
# DOI                                                                                    10.1109/smc.2013.744
# Country                                                                                                 USA
# Robot/s used (?)                                                                                     Darwin
# Adult vs Children                                                                                        Ad
# wtype                                                                                                  2013
# Role (Pr = presenter, TA = teaching assistant, Te = teacher, Pe = peer, Tu = tutor)                      Tu
# Curriculum                                                                                             math
# nb students per robot                                                                                     1
# students_nb                                                                                               1
# Communicative gestures vs functional actions                                                             CO
# WoZ                                                                                                      No
# Autonomy                                                                                           scripted
# Contain Retention component?                                                                             No
# Matos                                                                                                tablet
# Material                                                                                             tablet
# Included                                                                                                Yes
# Name: 44, dtype: object
# 10.1109/smc.2013.744
